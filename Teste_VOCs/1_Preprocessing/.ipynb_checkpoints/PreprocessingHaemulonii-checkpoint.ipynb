# %%
#%pip install ipywidgets
#%pip install pandas-profiling
#%pip install sweetviz
#%pip install autoviz
#%pip install dtale
#%pip install umap-learn

# %%
import pandas as pd
import umap.umap_ as umap
#import sweetviz #usado mais pra dados rotulados
import dtale
import numpy as np
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
sns.set(style='white', context='notebook', rc={'figure.figsize':(14,10)})

# %%
rootPath = "C:\\Users\\mlb\\Teste_VOCs\\DataFiles"
columnsName = ["0","1","timestamp","TGS826","TGS2611","TGS2603","TGS813","TGS822","TGS2602","TGS823","temperatura","pressao","umidade"]
columnsName2 = ["index","timestamp","TGS826","TGS2611","TGS2603","TGS813","TGS822","TGS2602","TGS823","temperatura","pressao","umidade","culture_day","c_type"]

# %%
#Load albicans file data
#data dictionary
# Albicans = 1
# Glabrata = 2
# Haemulonii = 3
# Kodamaea_ohmeri = 4
# Krusei = 5
# Parapsilosis = 6

#Load Haemulonii file data haemulonii_48hs_leitura1
df_haemulonii_48h = pd.read_csv(rootPath+"\\haemulonii_48hs_leitura1.csv", delim_whitespace=True, header=None, names=columnsName)
df_haemulonii_48h = df_haemulonii_48h.drop(["0","1"], axis=1)
df_haemulonii_48h.dropna(inplace=True)
df_haemulonii_48h.reset_index(inplace=True)
df_haemulonii_48h['c_type'] = 3
df_haemulonii_48h['culture_day'] = 2

# %%
df_haemulonii_48h.head()
# Out:
#    index     timestamp   TGS826  TGS2611  TGS2603   TGS813  TGS822  TGS2602  \
# 0      0  1.623863e+09  78650.0   3814.0  12430.0  31460.0  1985.0  13760.0
# 1      1  1.623863e+09  78650.0   3814.0  12440.0  31420.0  1985.0  13760.0
# 2      2  1.623863e+09  78700.0   3814.0  12430.0  31440.0  1984.0  13760.0
# 3      3  1.623863e+09  78350.0   3814.0  12430.0  31420.0  1986.0  13760.0
# 4      4  1.623863e+09  78650.0   3814.0  12430.0  31420.0  1985.0  13760.0
#
#    TGS823  temperatura  pressao  umidade  c_type  culture_day
# 0  7650.0        63.40    99.91     9.11       3            2
# 1  7648.0        63.40    99.87     9.13       3            2
# 2  7648.0        63.42    99.91     9.11       3            2
# 3  7648.0        63.40    99.95     8.96       3            2
# 4  7650.0        63.42    99.95     9.14       3            2

# %%
df_haemulonii_48h.describe()
# Out:
#              index     timestamp       TGS826       TGS2611       TGS2603  \
# count  6809.000000  6.809000e+03   6809.00000   6809.000000   6809.000000
# mean   3494.482303  1.623866e+09  36571.57145  35052.796446  23942.730210
# std    2017.575224  1.875550e+03  14542.17915  12551.453471   3668.955963
# min       0.000000  1.623863e+09  14380.00000   3814.000000  12430.000000
# 25%    1747.000000  1.623865e+09  24850.00000  22810.000000  21170.000000
# 50%    3496.000000  1.623866e+09  31930.00000  40410.000000  23760.000000
# 75%    5241.000000  1.623868e+09  48670.00000  46700.000000  27780.000000
# max    6986.000000  1.623870e+09  78700.00000  52380.000000  28390.000000
#
#              TGS813       TGS822       TGS2602       TGS823  temperatura  \
# count   6809.000000  6809.000000   6809.000000  6809.000000  6809.000000
# mean   27697.231605   493.618725   1869.945264  4356.369217    61.099906
# std     4065.521495   207.996283   1000.971550  1268.093146     1.184965
# ...

# %%
d = dtale.show(df_haemulonii_48h)
d.open_browser()

# %%
d = dtale.show(df_haemulonii_48h.drop(columns=['c_type','index']))
d.open_browser()
# Out:
# D:\Pessoais\Doutorado\2_Semestre\Ambiente_de_desenvolvimento\envs\Teste_VOCS\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# D:\Pessoais\Doutorado\2_Semestre\Ambiente_de_desenvolvimento\envs\Teste_VOCS\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning:
#
# invalid value encountered in true_divide

# %%
df_haemulonii_48h.to_csv(r'DatasetsJoined\AllHaemuloniiCollect.csv', index = False)
df_haemulonii_48h.to_csv(r'NewDatasets\NewHaemulonii.csv', index = False)

# %%
haemulonii_data = df_haemulonii_48h.drop(columns=['c_type'])
scaled_haemulonii_df = StandardScaler().fit_transform(haemulonii_data)
scaled_haemulonii_df
# Out:
# array([[-1.73214802, -1.72438998,  2.89375604, ...,  1.03819502,
#          0.27269238,  0.        ],
#        [-1.73165234, -1.7240449 ,  2.89375604, ...,  1.03627822,
#          0.28171731,  0.        ],
#        [-1.73115666, -1.72367487,  2.89719457, ...,  1.03819502,
#          0.27269238,  0.        ],
#        ...,
#        [ 1.72968716,  1.71196122,  0.75568011, ..., -1.08705284,
#         -1.21190892,  0.        ],
#        [ 1.73018285,  1.71232747,  0.76874651, ..., -1.09807442,
#         -1.1487344 ,  0.        ],
#        [ 1.73067853,  1.71259848,  0.76462028, ..., -1.07938566,
#         -1.18032166,  0.        ]])

# %%
reducer = umap.UMAP()

# %%
#Usa os dados reescalonados para a redução de dimensionalidade
embedding = reducer.fit_transform(scaled_haemulonii_df)
embedding.shape
# Out:
# (6809, 2)

# %%
#Usa as classes do array original pra plotar a 
# plt.scatter(
#     embedding[:, 0],
#     embedding[:, 1],
#     c=[sns.color_palette()[x] for x in df_albicans_joined.c_type])
# plt.gca().set_aspect('equal', 'datalim')
# plt.title('UMAP projection of the C. Albicans dataset', fontsize=24)

# %%
sns.scatterplot(data=embedding, x=embedding[:, 0], y=embedding[:, 1])
plt.legend(["Day 2"], loc='upper right', title="Culture days")
plt.title('UMAP projection of the C. Haemulonii dataset', fontsize=24)
# Out:
# Text(0.5, 1.0, 'UMAP projection of the C. Haemulonii dataset')

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(scaled_haemulonii_df)
result = pd.DataFrame(data = principalComponents
             , columns = ['PCA0', 'PCA1','PCA2'])

# %%
fig = plt.figure(figsize=[15,12])

ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(result['PCA0'], result['PCA1'], result['PCA2'], c=df_haemulonii_48h.culture_day, cmap="RdYlGn_r", s=50, ec='black')
handles, labels = scatter.legend_elements()
legend2 = ax.legend(handles, ["Day 1","Day 2"], loc="upper right", title="Culture days")

# make simple, bare axis lines through space:
xAxisLine = ((min(result['PCA0']), max(result['PCA0'])), (0, 0), (0,0))
ax.plot(xAxisLine[0], xAxisLine[1], xAxisLine[2], 'r')
yAxisLine = ((0, 0), (min(result['PCA1']), max(result['PCA1'])), (0,0))
ax.plot(yAxisLine[0], yAxisLine[1], yAxisLine[2], 'r')
zAxisLine = ((0, 0), (0,0), (min(result['PCA2']), max(result['PCA2'])))
ax.plot(zAxisLine[0], zAxisLine[1], zAxisLine[2], 'r')

# label the axes
ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_zlabel("PC3")
ax.set_title("PCA projection of the C. Haemulonii dataset")
# Out:
# Text(0.5, 0.92, 'PCA projection of the C. Haemulonii dataset')

# %%
pca2 = PCA(n_components=2)
principalComponents2 = pca2.fit_transform(scaled_haemulonii_df)
result2 = pd.DataFrame(data = principalComponents2
             , columns = ['PCA0', 'PCA1'])

# %%
ax = sns.scatterplot(data=result2, x=result2['PCA0'], y=result2['PCA1'],cmap="RdYlGn_r", s=20, ec='black',  hue=df_haemulonii_48h.culture_day)
handles, labels  =  ax.get_legend_handles_labels()
plt.legend(handles, ["Day 2"], loc='lower right', title="Culture days")
plt.title('PCA projection of the C. Haemulonii dataset', fontsize=24)
# Out:
# Text(0.5, 1.0, 'PCA projection of the C. Haemulonii dataset')
