# %%
#%pip install tpot

# %%
import pandas as pd
import umap.umap_ as umap
#import sweetviz #usado mais pra dados rotulados
import dtale
import numpy as np
import sklearn
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import autokeras as ak
import keras 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D,Dropout
from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.utils import to_categorical

from sklearn import preprocessing
from sklearn.svm import SVC 
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.neighbors import KNeighborsClassifier

import tpot
from tpot import TPOTClassifier

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
# Out:
# D:\Pessoais\Doutorado\2_Semestre\Ambiente_de_desenvolvimento\envs\Teste_VOCS\lib\site-packages\tpot\builtins\__init__.py:36: UserWarning:
#
# Warning: optional dependency `torch` is not available. - skipping import of NN models.

# %%
rootPath = "C:\\Users\\mlb\\Teste_VOCs\\1_Preprocessing\\NewDatasets"
columnsName_X = ["TGS826","TGS2611","TGS2603","TGS813","TGS822","TGS2602","TGS823","temperatura","pressao","umidade","culture_day"]

# %%
#Load albicans file data
#data dictionary
# Albicans = 1
# Glabrata = 2
# Haemulonii = 3
# Kodamaea_ohmeri = 4
# Krusei = 5
# Parapsilosis = 6

AllCandidasCollect    = pd.read_csv(rootPath+"\\AllCandidasCollect.csv", sep=",")

# %%
AllCandidasCollect
# Out:
#         TGS826  TGS2611  TGS2603   TGS813  TGS822  TGS2602  TGS823  \
# 0      91720.0   7305.0   6014.0  63460.0  4294.0  40700.0  8005.0
# 1      91910.0   7305.0   6020.0  63380.0  4293.0  40730.0  7998.0
# 2      91190.0   7305.0   6020.0  63460.0  4294.0  40750.0  7998.0
# 3      92380.0   7305.0   6020.0  64470.0  4319.0  40770.0  7998.0
# 4      35120.0   7305.0   7841.0  64730.0  2047.0  16630.0  7032.0
# ...        ...      ...      ...      ...     ...      ...     ...
# 64961  87790.0   7171.0   8935.0  38260.0  2307.0  15180.0  7706.0
# 64962  86770.0   7171.0   8941.0  38200.0  2305.0  15180.0  7710.0
# 64963  87190.0   7171.0   8941.0  38260.0  2307.0  15180.0  7704.0
# 64964  87190.0   7171.0   8941.0  38330.0  2297.0  15170.0  7706.0
# 64965  87190.0   7178.0   8941.0  38390.0  2302.0  15180.0  7706.0
#
#        temperatura  pressao  umidade  c_type  culture_day
# 0            60.66   100.22    12.59       1            1
# 1            60.71   100.15    12.52       1            1
# 2            60.70   100.19    12.56       1            1
# 3            60.69    83.83    12.60       1            1
# 4            60.62    74.81    11.56       1            1
# ...            ...      ...      ...     ...          ...
# 64961        57.33    54.08     7.23       6            2
# 64962        57.32    54.00     7.25       6            2
# 64963        57.30    54.08     7.40       6            2
# 64964        57.29    54.08     7.25       6            2
# 64965        57.29    54.04     7.43       6            2
#
# [64966 rows x 12 columns]

# %%
X = AllCandidasCollect.drop(columns=['c_type'])
y = AllCandidasCollect['c_type']
y_sorted , y_description = pd.factorize(AllCandidasCollect['c_type'], sort=False)
categorical_labels_y = to_categorical(y_sorted)

# %%
def evaluate_model(model, n_interaction):
    array_acc = []
    array_precision = []
    array_recall = []
    array_f1 = []
    for i in range(n_interaction):
        accuracy = np.mean(cross_val_score(model, X, y, cv=StratifiedKFold(n_splits=10, shuffle=True)
                                           ,scoring=['precision_macro','recall_macro','f1_macro','accuracy']))
        array_acc.append(accuracy)

        #precision = np.mean(cross_val_score(model, X, y, cv=StratifiedKFold(n_splits=10, shuffle=True), scoring='precision_macro'))
        #array_precision.append(precision)

       # recall = np.mean(cross_val_score(model, X, y, cv=StratifiedKFold(n_splits=10, shuffle=True), scoring='recall_macro'))
        #array_recall.append(recall)

       # f1 = np.mean(cross_val_score(model, X, y, cv=StratifiedKFold(n_splits=10, shuffle=True), scoring='f1_macro'))
       # array_f1.append(f1)

        #print(f"Iteração:{i} - Acurracy:{accuracy} - Precision:{precision} - Recall:{recall} - F1:{f1}")
    create_chart(array_acc)
    #return np.mean(accuracy), np.mean(precision),np.mean(recall),np.mean(f1), np.std(accuracy)
    return array_acc

# %%
def create_chart(array_acc):
    fig, graf = plt.subplots(figsize=(20,10))

    graf.set_title('Resultado Análise com kfod = 10')
    graf.plot(list(range(len(array_acc))), array_acc,color='#FF0000', label='Acurácia', linewidth=2, alpha=0.5)
    graf.plot(list(range(len(array_acc))),[np.mean(array_acc)]*len(array_acc),color='#0000FF', label='Média', linewidth=2, alpha=0.5)
    graf.plot(list(range(len(array_acc))),[np.median(array_acc)]*len(array_acc),color='#00FF00', label='Mediana', linewidth=2, alpha=0.5)
    graf.legend()
    print(f"Média da acurácia para {len(array_acc)} repetições: {np.mean(array_acc)}")

# %%
#knn = KNeighborsClassifier(n_neighbors = 6, weights= 'uniform', algorithm='kd_tree',  n_jobs =2)
#print(evaluate_model(knn, 30))

# %%
svm = SVC(kernel='linear', gamma=1, C=1, decision_function_shape='ovo')
print(evaluate_model(svm, 30))

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(random_state=5, max_iter=500, alpha=1e-5, hidden_layer_sizes=(500,), activation='relu')
print(evaluate_model(mlp, 30))

# %%
param_grid = {'C': [0.1,1, 10, 100], 'gamma': [1,0.1,0.01,0.001],'kernel': ['rbf', 'poly', 'sigmoid','linear']}
kernels = ['Polynomial', 'RBF', 'Sigmoid','Linear']#A function which returns the corresponding SVC model
def getClassifier(ktype):
    if ktype == 0:
        # Polynomial kernal
        return SVC(kernel='poly', degree=8, gamma="auto", decision_function_shape='ovo')
    elif ktype == 1:
        # Radial Basis Function kernal
        return SVC(kernel='rbf', gamma="auto",decision_function_shape='ovo')
    elif ktype == 2:
        # Sigmoid kernal
        return SVC(kernel='sigmoid', gamma="auto",decision_function_shape='ovo')
    elif ktype == 3:
        # Linear kernal
        return SVC(kernel='linear', gamma="auto",decision_function_shape='ovo')

# %%
min_max_scaler = preprocessing.MinMaxScaler()
#standardScaler = preprocessing.StandardScaler()
y = df['TypeOfGlass']
x_scaled = min_max_scaler.fit_transform(AllCandidasCollect.drop['c_type'])
#df_scaled = standardScaler.fit_transform(df)
x_scaled = pd.DataFrame(x_scaled, columns=columsNamesX)

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, random_state=1)
y_test = y_test.to_numpy()
y_train = y_train.to_numpy()
X_train = X_train.to_numpy()
X_test  = X_test.to_numpy()

# %%
#clf = ak.StructuredDataClassifier(overwrite=True, max_trials=3)
# Feed the structured data classifier with training data.
#clf.fit(X_train, y_train, epochs=10)
# Predict with the best model.
#predicted_y = clf.predict(X_test)
# Evaluate the best model with testing data.
#print(clf.evaluate(X_test, y_test))
# Out:
# Trial 3 Complete [00h 00m 24s]
# val_accuracy: 0.7581309080123901
#
# Best val_accuracy So Far: 0.969123125076294
# Total elapsed time: 00h 01m 11s
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/10
# 1523/1523 [==============================] - 2s 1ms/step - loss: 0.7118 - accuracy: 0.7274: 0s - loss: 0.783
# Epoch 2/10
# 1523/1523 [==============================] - 2s 1ms/step - loss: 0.4042 - accuracy: 0.8635
# Epoch 3/10
# 1523/1523 [==============================] - 2s 1ms/step - loss: 0.3132 - accuracy: 0.9021: 0s - loss: 0.3132 - accuracy: 0.90
# Epoch 4/10
# 1523/1523 [==============================] - 2s 1ms/step - loss: 0.2578 - accuracy: 0.9237: 1s - loss: 0.273 - ETA: 0s -
# Epoch 5/10
# 1523/1523 [==============================] - 2s 1ms/step - loss: 0.2202 - accuracy: 0.9365
# Epoch 6/10
# 1523/1523 [==============================] - ETA: 0s - loss: 0.1923 - accuracy: 0.94 - 2s 1ms/step - loss: 0.1923 - accuracy: 0.9444
# Epoch 7/10
# 1523/1523 [==============================] - 2s 1ms/step - loss: 0.1711 - accuracy: 0.9504: 0s - loss: 0.1760  - ETA: 0s - loss: 0.1734 -
# Epoch 8/10
# 1523/1523 [==============================] - 2s 1ms/step - loss: 0.1542 - accuracy: 0.9562
# Epoch 9/10
# 1523/1523 [==============================] - 2s 1ms/step - loss: 0.1404 - accuracy: 0.9607
# Epoch 10/10
# 1523/1523 [==============================] - 2s 1ms/step - loss: 0.1290 - accuracy: 0.9644
# INFO:tensorflow:Assets written to: .\structured_data_classifier\best_model\assets
# 508/508 [==============================] - 0s 902us/step
# 508/508 [==============================] - 1s 1ms/step - loss: 0.1338 - accuracy: 0.9682
# [0.13380111753940582, 0.9681689739227295]

# %%
#cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# define search
#model = TPOTClassifier(generations=5, population_size=50, cv=cv, scoring='accuracy', verbosity=2, random_state=1, n_jobs=-1)
# perform the search
#model.fit(X, y)
# export the best model
#model.export('tpot_best_model.py')
# Out:
# Optimization Progress:   0%|          | 0/300 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.9986659735970095
#
# Generation 2 - Current best internal CV score: 0.9986659735970095
#
# Generation 3 - Current best internal CV score: 0.9986659735970095
#
# Generation 4 - Current best internal CV score: 0.9986659735970095
#
# Generation 5 - Current best internal CV score: 0.9986659735970095
#
# Best pipeline: ExtraTreesClassifier(input_matrix, bootstrap=False, criterion=gini, max_features=0.9500000000000001, min_samples_leaf=6, min_samples_split=3, n_estimators=100)

# %%
input_dim = X_train.shape[1]
print(input_dim)
nb_classes = len(categorical_labels_y[0])
print(nb_classes)
print(np.shape(X_train))
print(np.shape(y_train))

# %%
from tensorflow.keras.optimizers import SGD
num_epochs = 500
batch_size = 5000

array_history = []
array_score = []

for i in range(0,1):
    print("################## ITERAÇÃO {} #############################".format(i))
    model = Sequential()

    # pamarâmetros Dense 17 = número de nós de entrada (input_dim*2)-1,
    # input_dim = número de dimensões do problema 
    # relu = função de ativação
    X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X,categorical_labels_y, test_size=0.3, random_state=2)
    
    model.add(Dense(((input_dim*4)-1), input_dim=input_dim, activation='relu')) # camada de entrada

    model.add(Dense(128,  activation="relu"))

    model.add(Dense(128,  activation="relu"))

    model.add(Dense(128,  activation="relu"))

    model.add(Dense(128,  activation="relu"))

    model.add(Dense(nb_classes, activation='softmax')) # camada de saída (o valor 6 é o número de classes do target)
    
    print(model.output_shape)
    
    model.summary()
    sgd = SGD(learning_rate=0.01, decay=1e-3, momentum=0.9, nesterov=True)
    model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
    hiatorical_s = model.fit(X_train, y_train, epochs=num_epochs,  batch_size=batch_size)
    array_history.append(hiatorical_s)
    score_s = model.evaluate(X_test, y_test, batch_size=batch_size)
    array_score.append(score_s)
    print("Score: {}% - Acurácia: {}%".format(score_s[0]*100,score_s[1]*100 ))
# Out:
# ################## ITERAÇÃO 0 #############################
# (None, 6)
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_81 (Dense)             (None, 43)                516
# _________________________________________________________________
# dense_82 (Dense)             (None, 128)               5632
# _________________________________________________________________
# dense_83 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_84 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_85 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_86 (Dense)             (None, 6)                 774
# =================================================================
# Total params: 56,458
# Trainable params: 56,458
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 10/10 [==============================] - 1s 17ms/step - loss: nan - accuracy: 0.2042
# Epoch 2/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 3/500
# 10/10 [==============================] - 0s 15ms/step - loss: nan - accuracy: 0.2203
# Epoch 4/500
# 10/10 [==============================] - 0s 15ms/step - loss: nan - accuracy: 0.2203
# Epoch 5/500
# 10/10 [==============================] - 0s 15ms/step - loss: nan - accuracy: 0.2203
# Epoch 6/500
# 10/10 [==============================] - 0s 15ms/step - loss: nan - accuracy: 0.2203
# Epoch 7/500
# 10/10 [==============================] - 0s 14ms/step - loss: nan - accuracy: 0.2203
# Epoch 8/500
# 10/10 [==============================] - 0s 15ms/step - loss: nan - accuracy: 0.2203
# Epoch 9/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 10/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 11/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 12/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 13/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 14/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 15/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 16/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 17/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 18/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 19/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 20/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 21/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 22/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 23/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 24/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 25/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 26/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 27/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 28/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 29/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 30/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 31/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 32/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 33/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 34/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 35/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 36/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 37/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 38/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 39/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 40/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 41/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 42/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 43/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 44/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 45/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 46/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 47/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 48/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 49/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 50/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 51/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 52/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 53/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 54/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 55/500
# 10/10 [==============================] - 0s 15ms/step - loss: nan - accuracy: 0.2203
# Epoch 56/500
# 10/10 [==============================] - 0s 15ms/step - loss: nan - accuracy: 0.2203
# Epoch 57/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 58/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 59/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 60/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 61/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 62/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 63/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 64/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 65/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 66/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 67/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 68/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 69/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 70/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 71/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 72/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 73/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 74/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 75/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 76/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 77/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 78/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 79/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 80/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 81/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 82/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 83/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 84/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 85/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 86/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 87/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 88/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 89/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 90/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 91/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 92/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 93/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 94/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 95/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 96/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 97/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 98/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 99/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 100/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 101/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 102/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 103/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 104/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 105/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 106/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 107/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 108/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 109/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 110/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 111/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 112/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 113/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 114/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 115/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 116/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 117/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 118/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 119/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 120/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 121/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 122/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 123/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 124/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 125/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 126/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 127/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 128/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 129/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 130/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 131/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 132/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 133/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 134/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 135/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 136/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 137/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 138/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 139/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 140/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 141/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 142/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 143/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 144/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 145/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 146/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 147/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 148/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 149/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 150/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 151/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 152/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 153/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 154/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 155/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 156/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 157/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 158/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 159/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 160/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 161/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 162/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 163/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 164/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 165/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 166/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 167/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 168/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 169/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 170/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 171/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 172/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 173/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 174/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 175/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 176/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 177/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 178/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 179/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 180/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 181/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 182/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 183/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 184/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 185/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 186/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 187/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 188/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 189/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 190/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 191/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 192/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 193/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 194/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 195/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 196/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 197/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 198/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 199/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 200/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 201/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 202/500
# 10/10 [==============================] - 0s 15ms/step - loss: nan - accuracy: 0.2203
# Epoch 203/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 204/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 205/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 206/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 207/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 208/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 209/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 210/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 211/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 212/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 213/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 214/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 215/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 216/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 217/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 218/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 219/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 220/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 221/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 222/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 223/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 224/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 225/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 226/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 227/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 228/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 229/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 230/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 231/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 232/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 233/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 234/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 235/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 236/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 237/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 238/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 239/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 240/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 241/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 242/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 243/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 244/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 245/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 246/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 247/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 248/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 249/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 250/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 251/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 252/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 253/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 254/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 255/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 256/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 257/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 258/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 259/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 260/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 261/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 262/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 263/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 264/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 265/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 266/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 267/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 268/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 269/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 270/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 271/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 272/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 273/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 274/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 275/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 276/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 277/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 278/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 279/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 280/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 281/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 282/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 283/500
# 10/10 [==============================] - 0s 15ms/step - loss: nan - accuracy: 0.2203
# Epoch 284/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 285/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 286/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 287/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 288/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 289/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 290/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 291/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 292/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 293/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 294/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 295/500
# 10/10 [==============================] - 0s 15ms/step - loss: nan - accuracy: 0.2203
# Epoch 296/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 297/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 298/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 299/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 300/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 301/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 302/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 303/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 304/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 305/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 306/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 307/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 308/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 309/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 310/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 311/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 312/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 313/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 314/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 315/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 316/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 317/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 318/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 319/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 320/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 321/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 322/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 323/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 324/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 325/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 326/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 327/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 328/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 329/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 330/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 331/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 332/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 333/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 334/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 335/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 336/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 337/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 338/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 339/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 340/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 341/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 342/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 343/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 344/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 345/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 346/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 347/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 348/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 349/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 350/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 351/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 352/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 353/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 354/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 355/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 356/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 357/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 358/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 359/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 360/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 361/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 362/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 363/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 364/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 365/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 366/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 367/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 368/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 369/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 370/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 371/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 372/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 373/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 374/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 375/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 376/500
# 10/10 [==============================] - 0s 27ms/step - loss: nan - accuracy: 0.2203
# Epoch 377/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 378/500
# 10/10 [==============================] - 0s 23ms/step - loss: nan - accuracy: 0.2203
# Epoch 379/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 380/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 381/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 382/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 383/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 384/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 385/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 386/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 387/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 388/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 389/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 390/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 391/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 392/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 393/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 394/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 395/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 396/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 397/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 398/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 399/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 400/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 401/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 402/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 403/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 404/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 405/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 406/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 407/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 408/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 409/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 410/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 411/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 412/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 413/500
# 10/10 [==============================] - 0s 21ms/step - loss: nan - accuracy: 0.2203
# Epoch 414/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 415/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 416/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 417/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 418/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 419/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 420/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 421/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 422/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 423/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 424/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 425/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 426/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 427/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 428/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 429/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 430/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 431/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 432/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 433/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 434/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 435/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 436/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 437/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 438/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 439/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 440/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 441/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 442/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 443/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 444/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 445/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 446/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 447/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 448/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 449/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 450/500
# 10/10 [==============================] - 0s 22ms/step - loss: nan - accuracy: 0.2203
# Epoch 451/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 452/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 453/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 454/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 455/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 456/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 457/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 458/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 459/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 460/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 461/500
# 10/10 [==============================] - 0s 28ms/step - loss: nan - accuracy: 0.2203
# Epoch 462/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 463/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 464/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 465/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 466/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 467/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 468/500
# 10/10 [==============================] - 0s 20ms/step - loss: nan - accuracy: 0.2203
# Epoch 469/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 470/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 471/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 472/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 473/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 474/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 475/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 476/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 477/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 478/500
# 10/10 [==============================] - 0s 21ms/step - loss: nan - accuracy: 0.2203
# Epoch 479/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 480/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 481/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 482/500
# 10/10 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.2203
# Epoch 483/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 484/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 485/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 486/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 487/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 488/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 489/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 490/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 491/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 492/500
# 10/10 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.2203
# Epoch 493/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 494/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 495/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 496/500
# 10/10 [==============================] - 0s 21ms/step - loss: nan - accuracy: 0.2203
# Epoch 497/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 498/500
# 10/10 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.2203
# Epoch 499/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# Epoch 500/500
# 10/10 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.2203
# 4/4 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.2229
# Score: nan% - Acurácia: 22.293484210968018%

# %%
#Usa os dados reescalonados para a redução de dimensionalidade
embedding = reducer.fit_transform(scaled_all_candidas_df)
embedding.shape
# Out:
# (64966, 3)

# %%
all_candidas_data2
# Out:
#         TGS826  TGS2611  TGS2603   TGS813  TGS822  TGS2602  TGS823  \
# 0      91720.0   7305.0   6014.0  63460.0  4294.0  40700.0  8005.0
# 1      91910.0   7305.0   6020.0  63380.0  4293.0  40730.0  7998.0
# 2      91190.0   7305.0   6020.0  63460.0  4294.0  40750.0  7998.0
# 3      92380.0   7305.0   6020.0  64470.0  4319.0  40770.0  7998.0
# 4      35120.0   7305.0   7841.0  64730.0  2047.0  16630.0  7032.0
# ...        ...      ...      ...      ...     ...      ...     ...
# 64961  87790.0   7171.0   8935.0  38260.0  2307.0  15180.0  7706.0
# 64962  86770.0   7171.0   8941.0  38200.0  2305.0  15180.0  7710.0
# 64963  87190.0   7171.0   8941.0  38260.0  2307.0  15180.0  7704.0
# 64964  87190.0   7171.0   8941.0  38330.0  2297.0  15170.0  7706.0
# 64965  87190.0   7178.0   8941.0  38390.0  2302.0  15180.0  7706.0
#
#        temperatura  pressao  umidade  culture_day
# 0            60.66   100.22    12.59            1
# 1            60.71   100.15    12.52            1
# 2            60.70   100.19    12.56            1
# 3            60.69    83.83    12.60            1
# 4            60.62    74.81    11.56            1
# ...            ...      ...      ...          ...
# 64961        57.33    54.08     7.23            2
# 64962        57.32    54.00     7.25            2
# 64963        57.30    54.08     7.40            2
# 64964        57.29    54.08     7.25            2
# 64965        57.29    54.04     7.43            2
#
# [64966 rows x 11 columns]

# %%
fig = plt.figure(figsize=[15,12])

ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(embedding[:, 0], embedding[:, 1], embedding[:, 2], c=all_candidas_data.c_type, cmap="tab10", s=30)
handles, labels = scatter.legend_elements()
legend2 = ax.legend(handles, ["C. Albicans", "C.Glabrata","C. Haemulonii","C. Kodamaea_ohmeri", "C. Krusei","C. Parapsilosis"], loc="upper right", title="Candidas types")

# make simple, bare axis lines through space:
xAxisLine = ((min(embedding[:, 0]), max(embedding[:, 0])), (0, 0), (0,0))
ax.plot(xAxisLine[0], xAxisLine[1], xAxisLine[2], 'r')
yAxisLine = ((0, 0), (min(embedding[:, 1]), max(embedding[:,1])), (0,0))
ax.plot(yAxisLine[0], yAxisLine[1], yAxisLine[2], 'r')
zAxisLine = ((0, 0), (0,0), (min(embedding[:, 2]), max(embedding[:, 2])))
ax.plot(zAxisLine[0], zAxisLine[1], zAxisLine[2], 'r')

# label the axes
ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_zlabel("PC3")
ax.set_title("UMAP projection from All Candidas dataset")
# Out:
# Text(0.5, 0.92, 'UMAP projection from All Candidas dataset')

# %%
# d = dtale.show(embedding)
# d.open_browser()

# %%
#Usa as classes do array original pra plotar a 
# Albicans = 1
# Glabrata = 2
# Haemulonii = 3
# Kodamaea_ohmeri = 4
# Krusei = 5
# Parapsilosis = 6
ax= sns.scatterplot(
    embedding[:, 0],
    embedding[:, 1],
    hue= all_candidas_data.c_type , s=15, cmap="tab10")
plt.gca().set_aspect('equal', 'datalim')
handles, labels  =  ax.get_legend_handles_labels()
#"C. Albicans", "C.Glabrata","C. Haemulonii","C. Albicans", "C.Glabrata","C. Haemulonii"
plt.legend(handles, ["C. Albicans", "C.Glabrata","C. Haemulonii","C. Kodamaea_ohmeri", "C. Krusei","C. Parapsilosis"], loc='lower right')
plt.title('UMAP projection of the All Candidas dataset', fontsize=24)
plt.show
# Out:
# D:\Pessoais\Doutorado\2_Semestre\Ambiente_de_desenvolvimento\envs\Teste_VOCS\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=all_candidas_data.c_type, cmap='Spectral', s=5)
plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(7)).set_ticks(np.arange(7))
plt.title('UMAP projection of the All Candidas dataset', fontsize=24);

# %%
scaled_all_candidas_df
# Out:
#          TGS826   TGS2611   TGS2603    TGS813    TGS822   TGS2602    TGS823  \
# 0      2.003269 -1.576283 -1.769974  2.954890  3.856102  4.848865  1.850200
# 1      2.010804 -1.576283 -1.769174  2.947788  3.855010  4.852878  1.846751
# 2      1.982249 -1.576283 -1.769174  2.954890  3.856102  4.855554  1.846751
# 3      2.029445 -1.576283 -1.769174  3.044555  3.883394  4.858229  1.846751
# 4     -0.241521 -1.576283 -1.526367  3.067637  1.403062  1.629130  1.370875
# ...         ...       ...       ...       ...       ...       ...       ...
# 64961  1.847403 -1.583619 -1.380496  0.717705  1.686902  1.435170  1.702904
# 64962  1.806949 -1.583619 -1.379696  0.712378  1.684719  1.435170  1.704875
# 64963  1.823606 -1.583619 -1.379696  0.717705  1.686902  1.435170  1.701919
# 64964  1.823606 -1.583619 -1.379696  0.723919  1.675986  1.433832  1.702904
# 64965  1.823606 -1.583235 -1.379696  0.729246  1.681444  1.435170  1.702904
#
#        temperatura   pressao   umidade  culture_day
# 0        -0.078346  1.069778  0.785722    -1.148069
# 1        -0.065637  1.066455  0.767577    -1.148069
# 2        -0.068179  1.068354  0.777945    -1.148069
# 3        -0.070720  0.291865  0.788314    -1.148069
# 4        -0.088514 -0.136247  0.518727    -1.148069
# ...            ...       ...       ...          ...
# 64961    -0.924797 -1.120147 -0.603685     0.871028
# 64962    -0.927339 -1.123944 -0.598501     0.871028
# 64963    -0.932423 -1.120147 -0.559618     0.871028
# 64964    -0.934965 -1.120147 -0.598501     0.871028
# 64965    -0.934965 -1.122046 -0.551842     0.871028
#
# [64966 rows x 11 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(scaled_all_candidas_df)
result = pd.DataFrame(data = principalComponents
             , columns = ['PCA0', 'PCA1','PCA2'])

# %%
fig = plt.figure(figsize=[15,12])

ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(result['PCA0'], result['PCA1'], result['PCA2'], c=all_candidas_data.c_type, cmap="tab10", s=30)
handles, labels = scatter.legend_elements()
legend2 = ax.legend(handles, ["C. Albicans", "C.Glabrata","C. Haemulonii","C. Kodamaea_ohmeri", "C. Krusei","C. Parapsilosis"], loc="upper right", title="Candidas types")

# make simple, bare axis lines through space:
xAxisLine = ((min(result['PCA0']), max(result['PCA0'])), (0, 0), (0,0))
ax.plot(xAxisLine[0], xAxisLine[1], xAxisLine[2], 'r')
yAxisLine = ((0, 0), (min(result['PCA1']), max(result['PCA1'])), (0,0))
ax.plot(yAxisLine[0], yAxisLine[1], yAxisLine[2], 'r')
zAxisLine = ((0, 0), (0,0), (min(result['PCA2']), max(result['PCA2'])))
ax.plot(zAxisLine[0], zAxisLine[1], zAxisLine[2], 'r')

# label the axes
ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_zlabel("PC3")
ax.set_title("PCA projection from All Candidas dataset")
# Out:
# Text(0.5, 0.92, 'PCA projection from All Candidas dataset')

# %%
components_df =  pd.DataFrame(abs(pca.components_[:3]),columns=scaled_all_candidas_df.columns,
                             index=['PCA1','PCA2','PCA3'])
components_df

#
# ['blue', 'orange', 'green', 'red', 'purple', 
#		'brown', 'pink', 'gray', 'olive', 'cyan']
# Out:
#         TGS826   TGS2611   TGS2603    TGS813    TGS822   TGS2602    TGS823  \
# PCA1  0.401875  0.364768  0.181390  0.308431  0.414364  0.401442  0.386019
# PCA2  0.159215  0.286915  0.469543  0.230078  0.056167  0.110432  0.227519
# PCA3  0.068096  0.003525  0.162966  0.169004  0.071166  0.068238  0.007459
#
#       temperatura   pressao   umidade  culture_day
# PCA1     0.271378  0.049836  0.136909     0.025904
# PCA2     0.030967  0.553797  0.490061     0.063237
# PCA3     0.506389  0.034451  0.332265     0.749958

# %%
d = dtale.show(components_df)
d.open_browser()

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(scaled_all_candidas_df)
result = pd.DataFrame(data = principalComponents
             , columns = ['PCA0', 'PCA1'])

# %%
ax = sns.scatterplot(data=result, x='PCA0', y='PCA1',cmap="tab10", s=50, c=all_candidas_data.c_type)
handles, labels  =  ax.get_legend_handles_labels()
handles, labels = scatter.legend_elements()
legend2 = ax.legend(handles, ["C. Albicans", "C.Glabrata","C. Haemulonii","C. Kodamaea_ohmeri", "C. Krusei","C. Parapsilosis"], loc="lower right", title="Candidas types")
plt.title('PCA projection from All Candidas dataset', fontsize=24)
# Out:
# Text(0.5, 1.0, 'PCA projection from All Candidas dataset')
